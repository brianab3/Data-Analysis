# %%
# Assignment 9: Pandas part 3  SOLUTION
# Work with Urbana station data

# %%
# >> A: Import needed modules -
#       NumPy, Matplotlib, and (now) Pandas
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# >> B: Get wind/precipitation data file
#  1. URL: rfd.atmos.uiuc.edu/305/Data/skyApr8.csv
#  2. Grab with wget (or wget -N -q to not reload if already have it, and 'quiet' mode)
#  3. Use 'head -4' as we did in past assignments to see the first few lines of text.
#     The first column should be device_id, which is always 17426.
# !wget -N -q rfd.atmos.uiuc.edu/305/Data/skyApr8.csv
# !head -4 skyApr8.csv
# Out:
# ﻿device_id,bucket_step_minutes,timestamp,lux,uv,precip,wind_lull,wind_avg,wind_gust,wind_dir,battery,report_interval,solar_radiation,local_daily_precip,precip_type,wind_interval,precip_final,local_daily_precip_final,precip_analysis_type
# 17426,1,1586304000,2046,0.08,0,0.49,2.12,3.84,235,3.07,1,17,10.575281,0,3,0,0,1
# 17426,1,1586304060,1956,0.08,0,0.89,1.97,3.4,236,3.07,1,16,10.575281,0,3,0,0,1
# 17426,1,1586304120,1880,0.07,0,1.74,3.32,4.92,237,3.07,1,15,10.575281,0,3,0,0,1

# %%
# >> C: Read the 'sky' wind/precipitation data
#  1. Read with Pandas read_csv(), into Pandas series named 'sky'
#  2. Add a name to the sky data object ... call it 'Sky'
#  3. Use the .head() function to see the first few lines.
Sky = pd.read_csv('skyApr8.csv')
Sky.head()
# Out:
#    device_id  bucket_step_minutes   timestamp   lux    uv  precip  wind_lull  \
# 0      17426                    1  1586304000  2046  0.08     0.0       0.49
# 1      17426                    1  1586304060  1956  0.08     0.0       0.89
# 2      17426                    1  1586304120  1880  0.07     0.0       1.74
# 3      17426                    1  1586304180  1782  0.07     0.0       1.03
# 4      17426                    1  1586304240  1692  0.07     0.0       0.76
#
#    wind_avg  wind_gust  wind_dir  battery  report_interval  solar_radiation  \
# 0      2.12       3.84       235     3.07                1               17
# 1      1.97       3.40       236     3.07                1               16
# 2      3.32       4.92       237     3.07                1               15
# 3      2.07       3.53       233     3.07                1               14
# 4      1.72       3.49       228     3.07                1               14
#
#    local_daily_precip  precip_type  wind_interval  precip_final  \
# 0           10.575281          0.0            3.0           0.0
# 1           10.575281          0.0            3.0           0.0
# 2           10.575281          0.0            3.0           0.0
# 3           10.575281          0.0            3.0           0.0
# 4           10.575281          0.0            3.0           0.0
#
#    local_daily_precip_final  precip_analysis_type
# 0                       0.0                     1
# 1                       0.0                     1
# 2                       0.0                     1
# 3                       0.0                     1
# 4                       0.0                     1

# %%
# >> D: Get and read the temperature / humidity data
#  1. Get this file: rfd.atmos.uiuc.edu/305/Data/airApr8.csv
#  2. Read with pandas as you did before, but into array "air"
#  3. Name the data object Air
#  4. Get a quick look at start of data with .head()
# !wget -N -q rfd.atmos.uiuc.edu/305/Data/airApr8.csv
air = pd.read_csv('airApr8.csv')
air.head()
# Out:
#    device_id  bucket_step_minutes   timestamp  pressure  temperature  \
# 0      17424                    1  1586304000     979.8         24.6
# 1      17424                    1  1586304060     979.7         24.6
# 2      17424                    1  1586304120     979.8         24.6
# 3      17424                    1  1586304180     979.8         24.6
# 4      17424                    1  1586304240     979.8         24.5
#
#    humidity  strike_count  strike_distance  battery  report_interval
# 0        50             0                0     3.43                1
# 1        50             0                0     3.43                1
# 2        50             0                0     3.43                1
# 3        50             0                0     3.43                1
# 4        50             0                0     3.43                1

# %%
# >> E: Get a quick summary of both data sets
#  1. Use array.describe() for each, in separate cells.
Sky.describe()
# Out:
#        device_id  bucket_step_minutes     timestamp            lux  \
# count     1437.0               1437.0  1.437000e+03    1437.000000
# mean     17426.0                  1.0  1.586347e+09   22478.924843
# std          0.0                  0.0  2.490662e+04   38015.470873
# min      17426.0                  1.0  1.586304e+09       0.000000
# 25%      17426.0                  1.0  1.586326e+09       0.000000
# 50%      17426.0                  1.0  1.586347e+09     194.000000
# 75%      17426.0                  1.0  1.586369e+09   17722.000000
# max      17426.0                  1.0  1.586390e+09  117359.000000
#
#                 uv       precip    wind_lull     wind_avg    wind_gust  \
# count  1437.000000  1437.000000  1437.000000  1437.000000  1437.000000
# mean      1.028727     0.010386     0.236521     0.871614     1.778372
# std       1.750914     0.080571     0.372545     0.696538     1.180634
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.260000     0.980000
# 50%       0.000000     0.000000     0.000000     0.800000     1.740000
# 75%       0.770000     0.000000     0.490000     1.380000     2.460000
# max       5.380000     1.330013     2.440000     5.320000    11.530000
#
#           wind_dir      battery  report_interval  solar_radiation  \
# count  1437.000000  1437.000000           1437.0      1437.000000
# mean    159.411969     3.058754              1.0       187.044537
# std     102.064074     0.010709              0.0       316.652551
# min       0.000000     3.040000              1.0         0.000000
# 25%      46.000000     3.050000              1.0         0.000000
# 50%     217.000000     3.060000              1.0         1.000000
# 75%     239.000000     3.070000              1.0       147.000000
# max     358.000000     3.080000              1.0       977.000000
#
#        local_daily_precip  precip_type  wind_interval  precip_final  \
# count         1437.000000  1436.000000         1436.0   1437.000000
# mean             2.603296     0.091226            3.0      0.006422
# std              4.625140     0.487509            0.0      0.049817
# min              0.000000     0.000000            3.0      0.000000
# 25%              0.000000     0.000000            3.0      0.000000
# 50%              0.000000     0.000000            3.0      0.000000
# 75%              0.015565     0.000000            3.0      0.000000
# max             14.925384     3.000000            3.0      0.822347
#
#        local_daily_precip_final  precip_analysis_type
# count               1437.000000                1437.0
# mean                   0.244545                   1.0
# std                    1.333732                   0.0
# min                    0.000000                   1.0
# 25%                    0.000000                   1.0
# 50%                    0.000000                   1.0
# 75%                    0.000000                   1.0
# max                    9.228365                   1.0

# %%
air.describe()
# Out:
#        device_id  bucket_step_minutes     timestamp     pressure  temperature  \
# count     1433.0               1433.0  1.433000e+03  1433.000000  1433.000000
# mean     17424.0                  1.0  1.586347e+09   980.904466    20.401675
# std          0.0                  0.0  2.485505e+04     1.902808     4.378633
# min      17424.0                  1.0  1.586304e+09   975.300000    14.200000
# 25%      17424.0                  1.0  1.586326e+09   980.000000    16.100000
# 50%      17424.0                  1.0  1.586347e+09   980.900000    20.100000
# 75%      17424.0                  1.0  1.586369e+09   982.300000    24.100000
# max      17424.0                  1.0  1.586390e+09   983.900000    27.700000
#
#           humidity  strike_count  strike_distance      battery  \
# count  1433.000000   1433.000000      1433.000000  1431.000000
# mean     57.461968      0.071179         0.247034     3.436499
# std      11.126940      0.593693         1.736188     0.006051
# min      29.000000      0.000000         0.000000     3.420000
# 25%      51.000000      0.000000         0.000000     3.430000
# 50%      60.000000      0.000000         0.000000     3.440000
# 75%      66.000000      0.000000         0.000000     3.440000
# max      76.000000      8.000000        14.000000     3.450000
#
#        report_interval
# count           1433.0
# mean               1.0
# std                0.0
# min                1.0
# 25%                1.0
# 50%                1.0
# 75%                1.0
# max                1.0

# %%
# >> F: Scale wind and temp data
#  1. The temperature data is degrees C. Convert it to deg. F.
#       You can use air.temperature = air.temperature * ...
#  2. Wind data is in meters per second.  Convert to mph.
#       Do this for three fields: wind lull (minimum 3 second sample),
#       wind avg (average over 1 minute), and gust columns.
#  3. Remember which data arrays (Pandas objects) contain
#       which data columns!
#  4. Note this CHANGES the data, so if you have to run this
#       cell more than once, you must re-read the CSV files
#       by rerunning one of the earlier Jupyter cells.
#  5. Print out the (new) max temperature and max wind gust to 3 DIGITS after the decimal point.
#       I found: 81.860 deg. F, and 25.757 mph.
#       Trees shielded the wind; Willard airport this day had 59 mph.
air.temperature = air.temperature * 1.8 + 32

Sky.wind_lull = Sky.wind_lull * 2.2369
Sky.wind_avg = Sky.wind_avg * 2.2369
Sky.wind_gust = Sky.wind_gust * 2.2369

# %%
print(max(Sky.wind_gust))
print(max(air.temperature))
# Out:
# 25.791456999999998
# 81.86

# %%
# >> G: Make a 2-row, 2-column plot.
#  1. Use Pandas .plot() -- NOT plt.plot
#  2. Top left: plot Three (!) fields using air['columnName'].plot() --
#        or, equivalently, use: air.columnName.plot() --
#     a) temperature (in red, figure out how, similar to matplotlib!)
#     b) humidity (this is RH) in green;
#     c) pressure (blue), and also add in plot(): secondary_y=True to use 2nd axis
#     d) add arguments ",legend=True" inside each of three .plot()
#     e) add title 'Temp (F), RH (%), Pres (mb)'
#  3. Top right: plot 3 fields - wind lull, average and gust; choose
#       varied colors to make these look distinct.  Add title 'Wind (mph)'
#       * Also: again, add legend=True to all three plot() statements.
#  4. Bottom left: you choose a different field.  Add a title!
#  5. Bottom right: wind direction, with kind='bar' (you choose color; add title)
#     * the x-axis for direction will be a mess - that's okay.
#  6. Go back and preface code with: plt.figure( figsize=...for larger fig, you choose size)
#  7. Finish with tight_layout
#  The arrival of the storms should be clear with the temperature drop,
#    the jump in humidity and pressure, and the wind gust.

plt.figure(figsize=(12,10))
plt.subplot(2,2,1);
air.temperature.plot(legend=True, color='red')
air.humidity.plot(legend=True, color='green')
air.pressure.plot(secondary_y=True,legend=True, color='blue')
secondary_y=True
plt.title('Temp (F), RH (%), Pres (mb)')

plt.subplot(2,2,2);
Sky.wind_lull.plot(color='orange', legend=True)
Sky.wind_avg.plot(color='blue', legend=True)
Sky.wind_gust.plot(color='yellow', legend=True)
plt.title('Wind (mph)')

plt.subplot(2,2,3);
air.temperature.plot(legend=True, color='tan')
air.pressure.plot(legend=True, color='purple', secondary_y=True)
Sky.wind_gust.plot(legend=True, color='darkblue')
Sky.wind_avg.plot(legend=True, color='darkgreen')
plt.title('Temperature (F) vs Wind Gust (MPH)')

plt.subplot(2,2,4);
Sky.wind_dir.plot(kind='bar', color='blue')
plt.title('Wind Direction')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %%
# >> H: Let's finally merge our two data sets into one DataFrame.
#  1. Info: https://jakevdp.github.io/PythonDataScienceHandbook/03.07-merge-and-join.html
#  2. In our case, the .merge command should include this argument:  on='timestamp'
#     df is our Pandas DataFrame object.  on= specifies the Merge Key.
#  3. Finish the cell with a line that just contains: df
#     ... this prints the start and end of the data.
#     ... there should be 1432 rows and 28 columns.
#  Going forward, we can now view df['temperature'] or df.wind_gust, etc.
df=pd.merge(Sky,air,on='timestamp')
df
# Out:
#       device_id_x  bucket_step_minutes_x   timestamp   lux    uv    precip  \
# 0           17426                      1  1586304000  2046  0.08  0.000000
# 1           17426                      1  1586304060  1956  0.08  0.000000
# 2           17426                      1  1586304120  1880  0.07  0.000000
# 3           17426                      1  1586304180  1782  0.07  0.000000
# 4           17426                      1  1586304240  1692  0.07  0.000000
# ...           ...                    ...         ...   ...   ...       ...
# 1427        17426                      1  1586390100    52  0.00  0.040307
# 1428        17426                      1  1586390160    55  0.00  0.066214
# 1429        17426                      1  1586390220    55  0.00  0.027814
# 1430        17426                      1  1586390280    55  0.00  0.005684
# 1431        17426                      1  1586390340    57  0.00  0.000000
#
#       wind_lull  wind_avg  wind_gust  wind_dir  ...  precip_analysis_type  \
# 0      1.096081  4.742228   8.589696       235  ...                     1
# 1      1.990841  4.406693   7.605460       236  ...                     1
# 2      3.892206  7.426508  11.005548       237  ...                     1
# 3      2.304007  4.630383   7.896257       233  ...                     1
# 4      1.700044  3.847468   7.806781       228  ...                     1
# ...         ...       ...        ...       ...  ...                   ...
# 1427   0.156583  3.109291   5.614619       133  ...                     1
# 1428   0.044738  3.735623   8.410744       134  ...                     1
# 1429   0.178952  2.952708   7.314663       132  ...                     1
# 1430   0.290797  2.729018   7.694936       135  ...                     1
# 1431   5.458036  7.292294   7.694936       185  ...                     1
#
#       device_id_y  bucket_step_minutes_y  pressure  temperature  humidity  \
# 0           17424                      1     979.8        76.28        50
# 1           17424                      1     979.7        76.28        50
# 2           17424                      1     979.8        76.28        50
# 3           17424                      1     979.8        76.28        50
# 4           17424                      1     979.8        76.10        50
# ...           ...                    ...       ...          ...       ...
# 1427        17424                      1     978.7        65.30        57
# 1428        17424                      1     978.7        65.30        57
# 1429        17424                      1     978.7        65.12        56
# 1430        17424                      1     978.7        65.12        56
# 1431        17424                      1     978.7        64.94        56
#
#       strike_count  strike_distance  battery_y  report_interval_y
# 0                0                0       3.43                  1
# 1                0                0       3.43                  1
# 2                0                0       3.43                  1
# 3                0                0       3.43                  1
# 4                0                0       3.43                  1
# ...            ...              ...        ...                ...
# 1427             0                0       3.45                  1
# 1428             0                0       3.45                  1
# 1429             0                0       3.45                  1
# 1430             0                0       3.45                  1
# 1431             0                0       3.45                  1
#
# [1432 rows x 28 columns]
# Warning: Total number of columns (28) exceeds max_columns (20) limiting to first (20) columns.

# %%
# >> I: Make a scatter plot with Matplotlib
#  1. Use plt.scatter between the temperature and humidity.
#  2. Add the c= argument to specify a field to color the
#       dots with (pressure works, or choose another)
#  3. Use plt.xlabel, ylabel appropriately
#  4. Add a title: ___ vs. ___ colored by ___
plt.figure(figsize=(20,5))

plt.subplot(1,3,1);
plt.scatter(x=air.temperature, y=air.humidity, c=air.pressure)
plt.xlabel('Temperature (F)')
plt.ylabel('Humidity')
plt.title('Temperature (F) vs. Humidity colored by Pressure (mb)')

plt.subplot(1,3,2);
plt.scatter(x=air.temperature, y=air.humidity, c=air.temperature)
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.title('Temperature (F) vs. Humidity colored by Temperature')
plt.tight_layout

plt.subplot(1,3,3);
plt.scatter(x=air.temperature, y=air.humidity, c=air.strike_count)
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.title('Temperature (F) vs. Humidity colored by Strike Count')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %%
# >> J: Make another scatter plot, this time with plotly
# Plot the same fields as a scatterplot, using a different package:  plotly.
#  1. Reference:  https://plotly.com/python/px-arguments/
#  2. You need this code:
#       import plotly.express as px
#       px.scatter(df, x=df.temperature, y=df.humidity, color=df.YouChoose, size=df.YouChoose)
#     ... replace the first YouChoose with the c= field from your prior matplotlib scatter()
#     ... replace the second YouChoose with another field - used for icon size!
#  I used temperature, humidity, pressure and wind_gust, for example.

import plotly.express as px
px.scatter(df, x=df.temperature, y=df.humidity, color=df.pressure, size=df.wind_gust)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="77705904-8bc4-43ea-ac35-c85c833315b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77705904-8bc4-43ea-ac35-c85c833315b6")) {                    Plotly.newPlot(                        "77705904-8bc4-43ea-ac35-c85c833315b6",                        [{"hovertemplate":"temperature=%{x}<br>humidity=%{y}<br>wind_gust=%{marker.size}<br>pressure=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[979.8,979.7,979.8,979.8,979.8,979.8,979.8,979.8,979.8,979.8,979.9,979.8,979.9,979.9,979.9,979.8,979.9,979.9,979.9,979.9,979.9,979.9,979.9,979.9,979.9,980.0,979.9,979.9,979.9,979.9,980.0,979.9,979.9,980.0,979.9,979.9,979.9,979.9,979.9,979.9,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,979.9,979.9,980.0,980.0,980.0,979.9,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,979.9,979.9,979.9,979.9,980.0,980.0,980.0,979.9,979.9,979.9,979.9,980.0,980.0,980.0,980.0,980.0,980.0,979.9,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,979.9,980.0,980.0,979.9,979.9,979.9,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,979.9,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,980.0,979.9,979.9,979.9,979.9,979.9,980.0,979.9,980.0,980.0,980.0,980.1,980.0,980.0,980.0,980.1,980.1,980.2,980.1,980.2,980.2,980.2,980.3,980.3,980.3,980.3,980.3,980.3,980.3,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.4,980.5,980.5,980.5,980.6,980.6,980.6,980.6,980.6,980.6,980.6,980.6,980.6,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.8,980.8,980.8,980.8,980.8,980.8,980.8,980.8,980.8,980.8,980.8,980.8,980.8,980.9,980.9,980.9,980.9,980.9,980.8,980.9,980.8,980.8,980.8,980.8,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.8,980.8,980.8,980.8,980.8,980.8,980.9,980.9,980.8,980.8,980.8,980.8,980.8,980.8,980.9,980.8,980.8,980.9,980.8,980.8,980.9,980.8,980.8,980.8,980.9,980.9,980.9,980.9,980.9,981.0,980.9,980.9,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.0,981.0,981.0,981.0,981.0,980.9,980.9,980.9,980.9,980.8,980.8,980.8,980.8,980.8,980.8,980.7,980.7,980.7,980.7,980.7,980.6,980.6,980.7,980.7,980.7,980.7,980.7,980.8,980.8,980.7,980.8,980.8,980.8,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.7,980.6,980.6,980.7,980.6,980.6,980.6,980.5,980.5,980.6,980.5,980.5,980.6,980.6,980.6,980.5,980.6,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.4,980.5,980.5,980.4,980.4,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.5,980.6,980.5,980.5,980.5,980.5,980.6,980.5,980.5,980.5,980.6,980.5,980.5,980.5,980.5,980.6,980.6,980.6,980.6,980.6,980.6,980.6,980.6,980.6,980.6,980.6,980.7,980.7,980.7,980.8,980.7,980.8,980.8,980.8,980.8,980.8,980.8,980.9,980.9,980.9,980.8,980.9,980.9,980.9,980.9,980.9,980.9,980.9,980.9,981.0,981.0,981.0,980.9,981.0,981.0,981.0,980.9,981.0,981.0,980.9,981.0,980.9,981.0,980.9,980.9,981.0,980.9,980.9,980.9,980.9,980.9,980.9,980.9,980.9,980.9,981.0,980.9,980.9,981.0,981.0,981.0,981.0,980.9,981.0,981.0,980.9,980.9,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.0,981.1,981.0,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.1,981.2,981.1,981.1,981.1,981.2,981.2,981.1,981.2,981.2,981.1,981.1,981.1,981.1,981.1,981.2,981.1,981.1,981.2,981.2,981.2,981.2,981.2,981.2,981.2,981.2,981.2,981.2,981.2,981.3,981.3,981.3,981.3,981.3,981.3,981.4,981.3,981.3,981.4,981.4 ...

# %%
# End of assignment 9.
